# %%
from trr265.data_provider import DataProvider

# %%
dp = DataProvider('/Users/hilmarzech/Projects/trr265/trr265/data/')

# %%
set(dp.get_mov_data().participant.unique()) - set(dp.get_two_day_data().participant.unique())
# Out:
# {'b058',
#  'b062',
#  'b154',
#  'b159',
#  'b174',
#  'b202',
#  'b209',
#  'd006',
#  'd022',
#  'd081',
#  'm032',
#  'm052',
#  'm062',
#  'm172'}

# %%
sorted(list(dp.get_mov_data().participant.unique()))
# Out:
# ['b001',
#  'b002',
#  'b012',
#  'b013',
#  'b015',
#  'b017',
#  'b018',
#  'b020',
#  'b024',
#  'b025',
#  'b026',
#  'b027',
#  'b028',
#  'b029',
#  'b030',
#  'b032',
#  'b033',
#  'b034',
#  'b036',
#  'b037',
#  'b041',
#  'b042',
#  'b044',
#  'b045',
#  'b048',
#  'b049',
#  'b050',
#  'b051',
#  'b056',
#  'b058',
#  'b059',
#  'b061',
#  'b062',
#  'b065',
#  'b067',
#  'b068',
#  'b070',
#  'b075',
#  'b076',
#  'b079',
#  'b080',
#  'b081',
#  'b082',
#  'b083',
#  'b084',
#  'b087',
#  'b088',
#  'b089',
#  'b098',
#  'b099',
#  'b101',
#  'b102',
#  'b104',
#  'b106',
#  'b107',
#  'b108',
#  'b109',
#  'b111',
#  'b114',
#  'b121',
#  'b124',
#  'b125',
#  'b128',
#  'b130',
#  'b131',
#  'b132',
#  'b133',
#  'b138',
#  'b140',
#  'b142',
#  'b144',
#  'b145',
#  'b146',
#  'b147',
#  'b152',
#  'b153',
#  'b154',
#  'b155',
#  'b157',
#  'b158',
#  'b159',
#  'b163',
#  'b165',
#  'b167',
#  'b171',
#  'b174',
#  'b177',
#  'b182',
#  'b187',
#  'b188',
# ...

# %%
dp.get_mov_data().query("participant=='d029'")
# Out:
# Empty DataFrame
# ...

# %%
set(dp.get_two_day_data().participant.unique()) - set(dp.get_mov_data().participant.unique())
# Out:
# set()
