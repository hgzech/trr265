# %%
#hide
#from your_lib.core import *

# %% [markdown]
# # TRR 265
#
# > This project handles the analysis of the TRR 265 data...

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Install

# %% [markdown]
# `pip install trr265` (not implemented yet)

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
import trr265
from trr265 import data_provider as dp
dp.get_two_day_data()
# Out:
#                mov_index participant starting_date       date  sampling_day  \
# two_day_index
# 0                    NaN        b001    2020-02-24 2020-02-22             1
# 1                    NaN        b001    2020-02-24 2020-02-23             2
# 2                    6.0        b001    2020-02-24 2020-02-24             3
# 3                    NaN        b001    2020-02-24 2020-02-25             4
# 4                    NaN        b001    2020-02-24 2020-02-26             5
# ...                  ...         ...           ...        ...           ...
# 139779               NaN        m234    2021-08-16 2022-08-12           364
# 139780               NaN        m234    2021-08-16 2022-08-13           365
# 139781               NaN        m234    2021-08-16 2022-08-14           366
# 139782               NaN        m234    2021-08-16 2022-08-15           367
# 139783               NaN        m234    2021-08-16 2022-08-16           368
#
#                MDBF_zufrieden  MDBF_ruhig  MDBF_wohl  MDBF_entspannt  \
# two_day_index
# 0                         NaN         NaN        NaN             NaN
# 1                         NaN         NaN        NaN             NaN
# 2                         2.0         6.0        7.0             1.0
# 3                         NaN         NaN        NaN             NaN
# 4                         NaN         NaN        NaN             NaN
# ...                       ...         ...        ...             ...
# 139779                    NaN         NaN        NaN             NaN
# 139780                    NaN         NaN        NaN             NaN
# 139781                    NaN         NaN        NaN             NaN
# 139782                    NaN         NaN        NaN             NaN
# 139783                    NaN         NaN        NaN             NaN
#
#                soziale_isolation  alternative_rewards  craving  limit  \
# two_day_index
# 0                            NaN                  NaN      NaN    NaN
# 1                            NaN                  NaN      NaN    NaN
# 2                            1.0                  4.0      1.0    NaN
# 3                            NaN                  NaN      NaN    NaN
# 4                            NaN                  NaN      NaN    NaN
# ...                          ...                  ...      ...    ...
# 139779                       NaN                  NaN      NaN    NaN
# 139780                       NaN                  NaN      NaN    NaN
# 139781                       NaN                  NaN      NaN    NaN
# 139782                       NaN                  NaN      NaN    NaN
# 139783                       NaN                  NaN      NaN    NaN
#
#                control                                             drinks  \
# two_day_index
# 0                  NaN  {'AnzahlFlascheWeisswein': None, 'AnzahlFlasch...
# 1                  NaN  {'AnzahlFlascheWeisswein': 0.0, 'AnzahlFlasche...
# 2                  NaN                                               None
# 3                  NaN                                               None
# 4                  NaN                                               None
# ...                ...                                                ...
# 139779             NaN                                               None
# 139780             NaN                                               None
# 139781             NaN                                               None
# 139782             NaN                                               None
# 139783             NaN                                               None
#
#                g_alc
# two_day_index
# 0                6.4
# 1               35.2
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 139779           NaN
# 139780           NaN
# 139781           NaN
# 139782           NaN
# 139783           NaN
#
# [139784 rows x 16 columns]
